# %% [markdown]
# # Question 1

# %%
a = 0
def b():
 global a
 a = c(a)
def c(a):
 return a + 2
b()
b()
b()
a
# Out:
# 6

# %% [markdown]
# ### It will Print output 6
# #### (1)First the global variable a is declared/initialized as 0.
# #### (2)Then the fuction b is declared, and it modifies variable a by calling the function c with a as an argument.
# #### (3)Then the function c takes the value of a addes 2 to it by passing it as an argument and returns the result.
# #### (4)Then the b function is called which call's c with a with o value as an arugument adds 2 to it
# #### (5)Then the b function is called 2nd time with a = 2 value and again adding 2 to it
# #### (6)Then the b function is called 3rd time with a=4 value and then adding 2 to it making it 6
# #### (7)Then finally the value of a declared with is 6

# %% [markdown]
# # Question 2

# %%
def fileLength(filename):
    try:
        infile = open(filename)
        content = infile.read()
        infile.close()
        return len(content)
    except FileNotFoundError:
        print(f"File {filename} not found.")
fileLength('midterm.py')
# Out:
# File midterm.py not found.

# %% [markdown]
# # Question 3

# %%
class Marsupial:
    def __init__(self):
        self.pouch = []
        
    def put_in_pouch(self, item):
        self.pouch.append(item)
        
    def pouch_contents(self):
        return self.pouch
class Kangaroo(Marsupial):
    def __init__(self, x=0, y=0):
        super().__init__()
        self.x = x
        self.y = y
        
    def jump(self, dx, dy):
        self.x += dx
        self.y += dy
        
    def __str__(self):
        return f"I am a Kangaroo located at coordinates ({self.x},{self.y})"
k = Kangaroo(0, 0)
k.put_in_pouch('doll')
k.put_in_pouch('firetruck')
k.put_in_pouch('kitten')
k.pouch_contents()
['doll', 'firetruck', 'kitten']
print(k)
k.jump(1,0)
k.jump(1,0)
k.jump(1,0)
print(k)
# Out:
# I am a Kangaroo located at coordinates (0,0)
# I am a Kangaroo located at coordinates (3,0)

# %% [markdown]
# # Question 4

# %%
def collatz(x):
    print(x)
    if x == 1:
        return
    elif x % 2 == 0:
        collatz(x // 2)
    else:
        collatz(3 * x + 1)
collatz(1)
print()
collatz(10)
# Out:
# 1
#
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %% [markdown]
# # Question 5

# %%
def binary(n):
    if n < 2:
        print(n, end="")
    else:
        binary(n // 2)
        print(n % 2, end="")
        
binary(0)
print()
binary(1)
print()
binary(3)
print()
binary(9)
# Out:
# 0
# 1
# 11
# 1001

# %% [markdown]
# # Question 6

# %%
from html.parser import HTMLParser


class HeadingParser(HTMLParser):
    def __init__(self):
        super().__init__()
        self.indent_level = 0

    def handle_starttag(self, tag, attrs):
        if tag.startswith('h'):
            print(' ' * self.indent_level, end='')
            print(self.get_starttag_text())
            self.indent_level += 1

    def handle_endtag(self, tag):
        if tag.startswith('h'):
            self.indent_level -= 1

    def handle_data(self, data):
        data = data.strip()
        if data and self.indent_level > 0:
            print(' ' * self.indent_level + data)


infile = open('w3c.html')
content = infile.read()
infile.close()


parser = HeadingParser()
parser.feed(content)
# Out:
# <html lang="en">
#  <head>
#   Change_me
#  <h1>
#   W3C Mission
#  <h2>
#   Principles

# %% [markdown]
# # Question 7

# %%
from urllib.request import urlopen
from urllib.parse import urlparse, urljoin
from bs4 import BeautifulSoup

def webdir(url, depth, indent=0):
    print(" " * indent + url)

    if depth == 0:
        return

    parts = urlparse(url)
    base_url = f"{parts.scheme}://{parts.netloc}"
    try:
        response = urlopen(url)
    except:
        return
    html = response.read().decode("utf-8")

    soup = BeautifulSoup(html, "html.parser")

    for link in soup.find_all("a"):
        href = link.get("href")
        if href.startswith("http"):
            new_url = href
        else:
            new_url = urljoin(base_url, href)
        webdir(new_url, depth - 1, indent + 4)
webdir("https://en.wikipedia.org/wiki/Python_(programming_language)", 2,0)
# Out:
# https://en.wikipedia.org/wiki/Python_(programming_language)
#     https://en.wikipedia.org#bodyContent
#         https://en.wikipedia.org#bodyContent
#         https://en.wikipedia.org/wiki/Main_Page
#         https://en.wikipedia.org/wiki/Special:Search
#         https://en.wikipedia.org/w/index.php?title=Special:CreateAccount&returnto=Main+Page
#         https://en.wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Main+Page
#         https://en.wikipedia.org/w/index.php?title=Special:CreateAccount&returnto=Main+Page
#         https://en.wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Main+Page
#         https://en.wikipedia.org/wiki/Help:Introduction
#         https://en.wikipedia.org/wiki/Special:MyContributions
#         https://en.wikipedia.org/wiki/Special:MyTalk
#         https://en.wikipedia.org/wiki/Main_Page
#         https://en.wikipedia.org/wiki/Wikipedia:Contents
#         https://en.wikipedia.org/wiki/Portal:Current_events
# ...

# %% [markdown]
# # Question 8

# %%
import sqlite3

conn = sqlite3.connect('climate_data.db')
conn.execute('CREATE TABLE climate_data (city text, country text, season text, temperature real, rainfall real)')

conn.executemany('INSERT INTO climate_data VALUES (?, ?, ?, ?, ?)', [
    ('Mumbai', 'India', 'Winter', 24.8, 5.9),
    ('Mumbai', 'India', 'Spring', 28.4, 16.2),
    ('Mumbai', 'India', 'Summer', 27.9, 1549.4),
    ('Mumbai', 'India', 'Fall', 27.6, 346.0),
    ('London', 'United Kingdom', 'Winter', 4.2, 207.7),
    ('London', 'United Kingdom', 'Spring', 8.3, 169.6),
    ('London', 'United Kingdom', 'Summer', 15.7, 157.0),
    ('London', 'United Kingdom', 'Fall', 10.4, 218.5),
    ('Cairo', 'Egypt', 'Winter', 13.6, 16.5),
    ('Cairo', 'Egypt', 'Spring', 20.7, 6.5),
    ('Cairo', 'Egypt', 'Summer', 27.7, 0.1),
    ('Cairo', 'Egypt', 'Fall', 22.2, 4.5)
])
conn.commit()

print("All the temperature data")
print()
result = conn.execute('SELECT temperature FROM climate_data')
print(list(result))
print()

print("All the cities, but without repetition.")
print()
result = conn.execute('SELECT DISTINCT city FROM climate_data')
print(list(result))
print()


print("All the records for India.")
print()
result = conn.execute('SELECT * FROM climate_data WHERE country = "India"')
print(list(result))
print()

print("All the Fall records.")
print()
result = conn.execute('SELECT * FROM climate_data WHERE season = "Fall"')
print(list(result))
print()

print("The city, country, and season for which the average rainfall is between 200 and 400 millimeters")
print()
result = conn.execute('SELECT city, country, season FROM climate_data WHERE rainfall BETWEEN 200 AND 400')
print(list(result))
print()

print("The city and country for which the average Fall temperature is above 20 degrees, in increasing temperature order")
print()
result = conn.execute('SELECT city, country FROM climate_data WHERE season = "Fall" GROUP BY city, country HAVING AVG(temperature) > 20 ORDER BY AVG(temperature) ASC')
print(list(result))
print()

print("The total annual rainfall for Cairo.")
print()
result = conn.execute('SELECT SUM(rainfall) FROM climate_data WHERE city = "Cairo"')
print(list(result))
print()

print("The total rainfall for each season.")
print()
result = conn.execute('SELECT season, SUM(rainfall) FROM climate_data GROUP BY season')
print(list(result))


conn.close()
# Out:
# All the temperature data
#
# [(24.8,), (28.4,), (27.9,), (27.6,), (4.2,), (8.3,), (15.7,), (10.4,), (13.6,), (20.7,), (27.7,), (22.2,)]
#
# All the cities, but without repetition.
#
# [('Mumbai',), ('London',), ('Cairo',)]
#
# All the records for India.
#
# [('Mumbai', 'India', 'Winter', 24.8, 5.9), ('Mumbai', 'India', 'Spring', 28.4, 16.2), ('Mumbai', 'India', 'Summer', 27.9, 1549.4), ('Mumbai', 'India', 'Fall', 27.6, 346.0)]
#
# All the Fall records.
#
# [('Mumbai', 'India', 'Fall', 27.6, 346.0), ('London', 'United Kingdom', 'Fall', 10.4, 218.5), ('Cairo', 'Egypt', 'Fall', 22.2, 4.5)]
#
# The city, country, and season for which the average rainfall is between 200 and 400 millimeters
#
# [('Mumbai', 'India', 'Fall'), ('London', 'United Kingdom', 'Winter'), ('London', 'United Kingdom', 'Fall')]
#
# The city and country for which the average Fall temperature is above 20 degrees, in increasing temperature order
#
# [('Cairo', 'Egypt'), ('Mumbai', 'India')]
#
# ...

# %% [markdown]
# # Question 9

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

uppercase_words = [word.upper() for word in words]
print(uppercase_words)

lowercase_words = [word.lower() for word in words]
print(lowercase_words)

word_lengths = [len(word) for word in words]
print(word_lengths)

word_info = [[word.upper(), word.lower(), len(word)] for word in words]
print(word_info)

long_words = [word for word in words if len(word) >= 4]
print(long_words)
# Out:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
# [3, 5, 5, 3, 5, 4, 3, 4, 3]
# [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]]
# ['quick', 'brown', 'jumps', 'over', 'lazy']

# %% [markdown]
# # END OF FILE
